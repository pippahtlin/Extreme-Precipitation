# %%
import pandas as pd

# %%
file_path = '/Users/pippalin/Desktop/consoldated_data_to_process.csv'

# read the data
data = pd.read_csv(file_path)
data
# Out:
#                            slug  site_id is_primary  \
# 0                    10kbrewing        1       True
# 1               10thlddemocrats        1       True
# 2                         12gop        1       True
# 3                         12gop        2        NaN
# 4                            14        1      False
# ...                         ...      ...        ...
# 7654    zaringraceyfordistrict3        1       True
# 7655                    zebking        1       True
# 7656               zivoticesobe        2        NaN
# 7657  zoglinforelcaminohospital        1       True
# 7658            zorayahightower        1       True
#
#                                       concatenated_text  token_count
# 0     10K Brewing is proposing a brew pub on a City ...          550
# 1                        Nicole Ng-A-Qui - Chair    ...          646
# 2     It's Convention Time State Convention May 17 &...          255
# ...
